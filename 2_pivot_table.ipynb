# %%
import pandas as pd
import numpy as np
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data_jobs.csv")
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df[df.job_title_short == "Data Scientist"][df.job_location == "Berlin, Germany"][df.job_via == "via LinkedIn"][["job_title", "job_location", "job_posted_date"]]
# Out:
# C:\Users\TFC\AppData\Local\Temp\ipykernel_10500\2585496430.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.job_title_short == "Data Scientist"][df.job_location == "Berlin, Germany"][df.job_via == "via LinkedIn"][["job_title", "job_location", "job_posted_date"]]
# C:\Users\TFC\AppData\Local\Temp\ipykernel_10500\2585496430.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.job_title_short == "Data Scientist"][df.job_location == "Berlin, Germany"][df.job_via == "via LinkedIn"][["job_title", "job_location", "job_posted_date"]]
#                                                 job_title     job_location  \
# 2915    Manager (w/m/d) - PEGA Data Scientist / PEGA D...  Berlin, Germany
# 6922    Startup Founder (September 2023) - Data Scient...  Berlin, Germany
# 11315                  Trainee Data Science (all genders)  Berlin, Germany
# ...

# %%
df.pivot_table(values = "salary_year_avg", index = "job_country", columns = "job_title_short", aggfunc = "median").sort_values(by = "Data Scientist", ascending = False)
# Out:
# job_title_short       Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Russia                             NaN        280000.0           NaN
# Cyprus                             NaN             NaN       51014.0
# United Arab Emirates               NaN             NaN       98500.0
# Luxembourg                         NaN             NaN       57600.0
# Sweden                         89100.0             NaN      105650.0
# ...                                ...             ...           ...
# Paraguay                           NaN             NaN           NaN
# Peru                               NaN             NaN      106837.5
# Senegal                            NaN             NaN      100500.0
# Slovenia                       30000.0             NaN           NaN
# Uruguay                            NaN             NaN      100500.0
#
# job_title_short       Data Engineer  Data Scientist  \
# job_country
# Russia                          NaN        285000.0
# ...

# %%
df["salary_rate"] = df["salary_rate"].dropna()

# %%
#Fetching Data Analyst jobs
data_analyst_jobs = df[(df.job_title_short == "Data Analyst") & (df.job_title)].head(10)
data_analyst_jobs
# Out:
#    job_title_short                                          job_title  \
# 1     Data Analyst                                       Data Analyst
# 12    Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18    Data Analyst                                       Data Analyst
# 31    Data Analyst                           Stage - Data Analyst F/H
# 34    Data Analyst  Data Analyst als Marketing Manager Automation ...
# 36    Data Analyst                                       Data Analyst
# 38    Data Analyst              Data Quality and Governance Analyst 1
# 46    Data Analyst  Data Analyst (Bangkok Based, relocation provided)
# 67    Data Analyst                  Stage - Data Analyste Finance H/F
# 68    Data Analyst                          Sr. Research Data Analyst
#
#                                       job_location  \
# 1                     Guadalajara, Jalisco, Mexico
# 12                                    Lyon, France
# ...

# %%
data_scientist_jobs = df[df.job_title_short == "Data Scientist"].head(10)
data_scientist_jobs
# Out:
#    job_title_short                                          job_title  \
# 9   Data Scientist                                  Data Scientist II
# 17  Data Scientist                             Data Science Team Lead
# 19  Data Scientist                                     Data Scientist
# 20  Data Scientist                                     Data Scientist
# 21  Data Scientist  Stage - data scientist – génération ia de donn...
# 24  Data Scientist                      Data Scientist (DataLab Team)
# 28  Data Scientist                                CRM Data Specialist
# 29  Data Scientist                                     Data Scientist
# 32  Data Scientist   Sr. Data Scientist (NLP) - Full-time / Part-time
# 40  Data Scientist        Data Scientist, Data Strategy and Analytics
#
#                                job_location  \
# 9                                  Anywhere
# 17                               Laurel, MD
# 19                 Pune, Maharashtra, India
# ...

# %%
df["salary_rate"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 785736    NaN
# 785737    NaN
# 785738    NaN
# 785739    NaN
# 785740    NaN
# Name: salary_rate, Length: 785741, dtype: object

# %%
job_via = df[df.job_via == "via LinkedIn"].head(10)
job_via
# Out:
#          job_title_short                                          job_title  \
# 2          Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 6   Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7          Data Engineer                                      Data Engineer
# 10         Data Engineer               Erfahrene*r Data Engineer*in (m/w/d)
# 13  Senior Data Engineer                               Senior Data Engineer
# 15         Data Engineer                                      Data Engineer
# 16         Data Engineer                                  Big Data Engineer
# 22         Data Engineer      Data Engineer / Développeur·euse Big Data F/H
# 24        Data Scientist                      Data Scientist (DataLab Team)
# 26         Data Engineer                                      Data Engineer
#
#                 job_location       job_via job_schedule_type  \
# 2            Berlin, Germany  via LinkedIn         Full-time
# ...

# %%
df

# %%
df_job_country_salary = df.pivot_table(values= "salary_year_avg", index="job_country", columns= "job_title_short", aggfunc="median")
df_job_country_salary.head(6)
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# Austria                       NaN             NaN      80850.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# Algeria                45000.0             NaN                        NaN
# Argentina              96773.0        71000.00                   101029.0
# Armenia                48750.0             NaN                    87021.0
# Australia             106712.5       139216.00                   101029.0
# ...

# %%
top_countries = df["job_country"].value_counts().head(6).index
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'France', 'Germany',
#        'Spain'],
#       dtype='object', name='job_country')

# %%
#filtering the top countries using the .loc[] function
df_job_country_salary = df_job_country_salary.loc[top_countries]
df_job_country_salary
# Out:
# job_title_short  Data Analyst  Data Engineer  Data Scientist
# job_country
# United States         90000.0       125000.0        130000.0
# India                100500.0       147500.0        114008.0
# United Kingdom        87750.0       110000.0        105300.0
# France                69175.0        98301.5         88128.0
# Germany              103750.0       147500.0        131560.0
# Spain                 91977.0       133000.0         88128.0

# %%
job_titles = ["Data Analyst", "Data Engineer", "Data Scientist"]

# %%
df_job_country_salary = df_job_country_salary[job_titles]
df_job_country_salary
# Out:
# job_title_short  Data Analyst  Data Engineer  Data Scientist
# job_country
# United States         90000.0       125000.0        130000.0
# India                100500.0       147500.0        114008.0
# United Kingdom        87750.0       110000.0        105300.0
# France                69175.0        98301.5         88128.0
# Germany              103750.0       147500.0        131560.0
# Spain                 91977.0       133000.0         88128.0

# %%
df_job_country_salary.plot(kind='bar', figsize=(10, 6), title='Median Salary by Country and Job Title')
plt.xlabel('Median Salary (Yearly)')
plt.ylabel('Country')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()
